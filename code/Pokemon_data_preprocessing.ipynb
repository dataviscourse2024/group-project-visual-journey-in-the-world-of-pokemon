# %%
import pandas as pd

# %% [markdown]
# ## The Complete Pokemon Dataset

# %%
# columns_to_read = ['name', 'pokedex_number']
# df = pd.read_csv('pokemon_complete.csv',usecols=columns_to_read)

# df.head()

# %%
df = pd.read_csv('pokemon_complete.csv')
df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
len(df)
# Out:
# 801

# %%
import zipfile
import os

zip_file_path = 'pokemon_jpg.zip'

output_dir = 'pokemon_jpg'
with zipfile.ZipFile(zip_file_path, 'r') as z:
    z.extractall(output_dir)

# %%
image_dir = 'pokemon_jpg/pokemon_jpg'

def map_image_filename(pokedex_number):
    return f"{pokedex_number}.jpg"

df['image_filename'] = df['pokedex_number'].apply(map_image_filename)

df.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  pokedex_number  sp_attack  sp_defense  \
# ...

# %%
df['image_exists'] = df['image_filename'].apply(lambda x: os.path.exists(os.path.join(image_dir, x)))

# %%
df_with_images = df[df['image_exists'] == True]
df_with_images.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  sp_attack  sp_defense  speed  type1  \
# ...

# %%
len(df_with_images)
# Out:
# 703

# %%
df_with_images['category'] = df_with_images['classfication'].apply(lambda x: x.split()[0])
# Out:
# <ipython-input-11-b97ce9371026>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_images['category'] = df_with_images['classfication'].apply(lambda x: x.split()[0])

# %%
df_with_images = df_with_images.drop(columns=['classfication'])

# %%
df_with_images
# Out:
#                              abilities  against_bug  against_dark  \
# 0          ['Overgrow', 'Chlorophyll']          1.0           1.0
# 1          ['Overgrow', 'Chlorophyll']          1.0           1.0
# 2          ['Overgrow', 'Chlorophyll']          1.0           1.0
# 3             ['Blaze', 'Solar Power']          0.5           1.0
# 4             ['Blaze', 'Solar Power']          0.5           1.0
# ..                                 ...          ...           ...
# 716                      ['Dark Aura']          1.0           0.5
# 717  ['Aura Break', 'Power Construct']          1.0           1.0
# 718                     ['Clear Body']          0.5           0.5
# 719                       ['Magician']          1.0           4.0
# 720                   ['Water Absorb']          0.5           1.0
#
#      against_dragon  against_electric  against_fairy  against_fight  \
# 0               1.0               0.5            0.5            0.5
# ...

# %%
from pprint import pprint
import json

column_mapping = {
    'against_fight': 'against_fighting'  # Rename `against_fight` to `against_fighting`
}
df.rename(columns=column_mapping, inplace=True)

type_effectiveness_data = {}
for _, row in df.iterrows():
    type_name = row['type1']
    effectiveness = {col.replace('against_', ''): row[col] for col in df.columns if col.startswith('against_')}
    type_effectiveness_data[type_name] = effectiveness

# pprint(type_effectiveness_data)
with open('type_effectiveness.json', 'w') as json_file:
    json.dump(type_effectiveness_data, json_file, indent=4)

print("JSON file saved as 'type_effectiveness.json'")
# Out:
# JSON file saved as 'type_effectiveness.json'

# %%
df_with_images.to_csv('pokemon_stats_with_images.csv', index=False)

# %% [markdown]
# ## Pokemon Dataset with Team Combat

# %%
df = pd.read_csv('combats.csv')
df.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151

# %%
columns_to_read = ['pokedex_number','name','attack','defense','hp','sp_attack','sp_defense']
stats_df = pd.read_csv('pokemon_complete.csv',usecols=columns_to_read)
comeback_df = pd.read_csv('combats.csv')

comeback_df = pd.merge(comeback_df, stats_df, left_on='First_pokemon', right_on='pokedex_number', suffixes=('', '_first'))

comeback_df = pd.merge(comeback_df, stats_df, left_on='Second_pokemon', right_on='pokedex_number', suffixes=('_first', '_second'))

comeback_df = comeback_df.drop(columns=['pokedex_number_first', 'pokedex_number_second'])

comeback_df.head()
# Out:
#    First_pokemon  Second_pokemon  Winner  attack_first  defense_first  \
# 0            266             298     298            35             55
# 1            702             701     701            58             57
# 2            191             668     668            30             30
# 3            237             683     683            95             95
# 4            151             231     151           100            100
#
#    hp_first name_first  sp_attack_first  sp_defense_first  attack_second  \
# 0        50    Silcoon               25                25             20
# 1        67    Dedenne               81                67             92
# 2        30    Sunkern               30                30             68
# 3        50  Hitmontop               35               110             72
# 4       100        Mew              100               100             60
#
#    defense_second  hp_second name_second  sp_attack_second  sp_defense_second
# ...

# %%
comeback_df = pd.merge(comeback_df, stats_df[['pokedex_number', 'name']], left_on='Winner', right_on='pokedex_number', suffixes=('', '_winner'))

comeback_df = comeback_df.drop(columns=['First_pokemon','Second_pokemon','Winner'])

comeback_df = comeback_df.rename(columns={'name': 'winner_name'})

comeback_df.head()
# Out:
#    attack_first  defense_first  hp_first name_first  sp_attack_first  \
# 0            35             55        50    Silcoon               25
# 1            58             57        67    Dedenne               81
# 2            30             30        30    Sunkern               30
# 3            95             95        50  Hitmontop               35
# 4           100            100       100        Mew              100
#
#    sp_defense_first  attack_second  defense_second  hp_second name_second  \
# 0                25             20              40         50     Azurill
# 1                67             92              75         78    Hawlucha
# 2                30             68              72         86      Pyroar
# 3               110             72              72        101  Aromatisse
# 4               100             60              60         90      Phanpy
#
#    sp_attack_second  sp_defense_second  pokedex_number winner_name
# ...

# %%
len(comeback_df)
# Out:
# 50000

# %%
comeback_df.to_csv('comeback_results.csv', index=False)
